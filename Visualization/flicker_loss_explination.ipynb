# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
t = np.array(range(100))
D = np.sqrt(t/100)

# %%
plt.rcParams.update({'font.size': 60})

# %%
plt.figure(figsize=(12, 8), dpi=600)
ax = plt.axes() 
ax.spines['top'].set_linewidth('6.0')
ax.spines['left'].set_linewidth('6.0')
ax.spines['right'].set_linewidth('6.0')
ax.spines['bottom'].set_linewidth('6.0')
plt.plot(t, D, linewidth =4.0, color='steelblue')
plt.savefig('I.pdf')

# %%
plt.figure(figsize=(12, 8), dpi=600)
ax = plt.axes() 
ax.spines['top'].set_linewidth('6.0')#设置边框线宽为2.0
ax.spines['left'].set_linewidth('6.0')#设置边框线宽为2.0
ax.spines['right'].set_linewidth('6.0')#设置边框线宽为2.0
ax.spines['bottom'].set_linewidth('6.0')#设置边框线宽为2.0
plt.plot(t, enf, linewidth =4.0, color='darkgoldenrod')
plt.savefig('enf.pdf')

# %%
enf = 0.15*np.sin(t/5)
enf2 = np.sin(t/4)

# %%
I = D+enf
I2 = D+enf2

# %%
kernal = np.ones(8)/8

# %%
plt.figure(figsize=(10, 6), dpi=600)
plt.plot(t, I)
plt.savefig('I.png')

# %%
mean_D = np.zeros(100)
mean_I = np.zeros(100)
mean_I2 = np.zeros(100)
for i in range(100):
    mean_D[i]=np.mean(D)
    mean_I[i]=np.mean(I)
    mean_I2[i]=np.mean(I2)

# %%
D[47]
# Out:
# 6.855654600401044

# %%
最大值及其下标
[0, 4, 16, 29, 42, 54, 66, 79, 91]
[0, 2.90929743, 4.98935825, 6.32005986, 7.39995403, 8.304845156754038, 9.123950264743229, 9.861839873010567, 10.537982886581226]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11434/368012499.py in <module>
# ----> 1 最大值及其下标
#       2 [4, 16, 29, 42, 54, 66, 79, 91]
#       3 [2.90929743, 4.98935825, 6.32005986, 7.39995403, 8.304845156754038, 9.123950264743229, 9.861839873010567, 10.537982886581226]
#
# NameError: name '最大值及其下标' is not defined

# %%
最小值及其下标
[9, 22, 34, 47, 59, 72, 85, 97]
[2.02246988, 3.69042555, 4.8695544, 5.857572572421647, 6.740114339525654, 7.493502520795454, 8.223457954173293, 8.86774936,]

# %% [markdown]
# #### max

# %%
x = [4, 16, 29, 42, 54, 66, 79, 91]
y = [2.90929743,  4.98935825, 6.32005986, 7.39995403, 8.304845156754038, 9.123950264743229, 9.861839873010567, 10.537982886581226]
z = np.polyfit(x, y, 3)  
p1 = np.poly1d(z)  
topline = p1(t)

# t = np.array(range(256))
# fit_sig = p1(t)

# %% [markdown]
# #### min

# %%
x = [9, 22, 34, 47, 59, 72, 85, 97]
y = [2.02246988, 3.69042555, 4.8695544, 5.857572572421647, 6.740114339525654, 7.493502520795454, 8.223457954173293, 8.86774936,]
z = np.polyfit(x, y, 3)  
p1 = np.poly1d(z)  
botline = p1(t)

# t = np.array(range(256))
# fit_sig = p1(t)

# %%
mean_t = np.zeros(100)
mean_b = np.zeros(100)
mean_m = np.zeros(100)
for i in range(100):
    mean_t[i]=np.mean(topline)
    mean_b[i]=np.mean(botline)
    mean_m[i]=np.mean(midline)

# %%
mean_I
# Out:
# array([6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
#        6.61662737, 6.61662737, 6.61662737, 6.61662737, 6.61662737,
# ...

# %%
mean_D
# Out:
# array([6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
#        6.61462947, 6.61462947, 6.61462947, 6.61462947, 6.61462947,
# ...

# %%
0.51872211, 0.92439964
53, 175

0.48957369, 0.83097606
84, 222
# Out:
# (84, 222)

# %%
# max

# %%
x = [ 8, 11, 38, 41, 72, 100]
y = [ 0.4327787529308448, 0.45293694, 0.7616293511016206, 0.78142201, 0.9933768,  1.1170385]
z = np.polyfit(x, y, 3) 
p1 = np.poly1d(z)  
topline = p1(t)

# t = np.array(range(256))
# fit_sig = p1(t)

# %%
0.45293694/2
# Out:
# 0.22646847

# %%
# min

# %%
x = [0, 22, 23, 54, 56, 86, 87]
y = [0,  0.32630126, 0.3305295017862523, 0.5877064883249797, 0.6014548179820907, 0.77782684, 0.7838389982382865]
z = np.polyfit(x, y, 3)
p1 = np.poly1d(z)
botline = p1(t)

# t = np.array(range(256))
# fit_sig = p1(t)

# %%
x = [2, 16, 31, 47, 63, 79, 93]
y = [0.22646847,  0.3896191, 0.553861635  ,0.6845642491624899, 0.7905416441624898, 0.88560182, 0.94743267 ]
z = np.polyfit(x, y, 3) 
p1 = np.poly1d(z)
midline = p1(t)

# t = np.array(range(256))
# fit_sig = p1(t)

# %%
(0.3305295017862523+0.45293694)/2
# Out:
# 0.3917332208931261

# %%
I
# Out:
# array([0.        , 0.1298004 , 0.19983411, 0.25790145, 0.30760341,
#        0.34982745, 0.38475484, 0.41239259, 0.43277875, 0.44607714,
#        0.45262238, 0.45293694, 0.44772964, 0.43788033, 0.42441396,
#        0.40846634, 0.39124388, 0.3739794 , 0.357886  , 0.34411121,
#        0.33369322, 0.3275212 , 0.32630126, 0.3305295 , 0.34047326,
#        0.35616136, 0.37738375, 0.40370057, 0.43446027, 0.46882615,
#        0.50581023, 0.54431303, 0.58316781, 0.62118747, 0.65721219,
#        0.69015597, 0.71905018, 0.74308247, 0.76162935, 0.7742813 ,
#        0.78085927, 0.78142201, 0.77626391, 0.76590342, 0.75106254,
#        0.73263817, 0.71166649, 0.68928177, 0.66667131, 0.64502813,
#        0.62550361, 0.60916164, 0.59693628, 0.58959468, 0.58770649,
#        0.59162132, 0.60145482, 0.61708416, 0.63815302, 0.66408581,
#        0.69411073, 0.72729058, 0.76256016, 0.79876885, 0.83472647,
#        0.86925083, 0.90121487, 0.92959166, 0.9534954 , 0.97221674,
# ...

# %%
plt.figure(figsize=(12, 8), dpi=600)
ax = plt.axes() 
ax.spines['top'].set_linewidth('6.0')
ax.spines['left'].set_linewidth('6.0')
ax.spines['right'].set_linewidth('6.0')
ax.spines['bottom'].set_linewidth('6.0')
plt.plot(t, I, linewidth =4.0, color='darkgoldenrod')
# plt.ylim(6.61,6.62)
plt.savefig('pure_D.pdf')

# %%
plt.figure(figsize=(10, 6), dpi=600)
plt.plot(t, mean_I, '--',color='darkgoldenrod')
plt.plot(t, mean_D, '--',color='steelblue')
plt.ylim(6.61,6.62)
plt.savefig('ylim_d.png')

# %%
plt.figure(figsize=(12, 8), dpi=600)
ax = plt.axes() 
ax.spines['top'].set_linewidth('6.0')
ax.spines['left'].set_linewidth('6.0')
ax.spines['right'].set_linewidth('6.0')
ax.spines['bottom'].set_linewidth('6.0')
plt.plot(t, I, linewidth =4.0, color='darkgoldenrod')
plt.plot(t, D, linewidth =4.0, color='steelblue')
plt.plot(t, topline, linewidth =4.0, linestyle='--', color='mediumvioletred')
plt.plot(t, botline, linewidth =4.0, linestyle='--', color='seagreen')
plt.plot(t, midline, linewidth =4.0, linestyle='--', color='black')
# plt.plot(t, mean_I, '--',color='darkgoldenrod')
# plt.plot(t, mean_D, '--',color='steelblue')
# plt.plot(t, mean_t,'--',color='mediumvioletred')
# plt.plot(t, mean_b,'--',color='seagreen')
# plt.ylim(6.61,6.62)
plt.savefig('D.pdf')

# %%
mean_b
# Out:
# array([0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
#        0.51824328, 0.51824328, 0.51824328, 0.51824328, 0.51824328,
# ...

# %%
plt.figure(figsize=(2, 8), dpi=600)
ax = plt.axes() 
ax.spines['top'].set_linewidth('6.0')
ax.spines['left'].set_linewidth('6.0')
ax.spines['right'].set_linewidth('6.0')
ax.spines['bottom'].set_linewidth('6.0')
plt.plot(t, mean_I, linewidth =4.0, color='darkgoldenrod')
plt.plot(t, mean_D, linewidth =4.0, color='steelblue')
plt.plot(t, mean_t, linewidth =4.0, linestyle='--',color='mediumvioletred')
plt.plot(t, mean_b, linewidth =4.0, linestyle='--',color='seagreen')
plt.plot(t, mean_m, linewidth =4.0, linestyle='--',color='black')
plt.xlim(0,1)
plt.savefig('mean_D_2.pdf')

# %%
plt.figure(figsize=(2, 8), dpi=600)
ax = plt.axes() 
ax.spines['top'].set_linewidth('6.0')
ax.spines['left'].set_linewidth('6.0')
ax.spines['right'].set_linewidth('6.0')
ax.spines['bottom'].set_linewidth('6.0')
plt.plot(t, mean_I, linewidth =4.0, color='darkgoldenrod')
plt.plot(t, mean_D, linewidth =4.0, color='steelblue')
plt.plot(t, mean_t, linewidth =4.0, linestyle='--',color='mediumvioletred')
plt.plot(t, mean_b, linewidth =4.0, linestyle='--',color='seagreen')
plt.plot(t, mean_m, linewidth =4.0, linestyle='--',color='black')
plt.ylim(0.659,0.667)
plt.xlim(0,1)
plt.savefig('mean_D2.pdf')
